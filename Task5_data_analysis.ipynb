# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
from plotly.offline import iplot

# %% [markdown]
# # Scenario 1

# %%
h0 = 10000
K_h = 0.01
df=pd.read_csv('lander_phase_space_1.csv')
h=np.arange(0, h0, 100)
v=-(0.5 + K_h * h)
df.head()
# Out:
#    Time  Altitude  Velocity
# 0   0.0  10000.00 -0.371467
# 1   0.1   9999.96 -0.371467
# 2   0.2   9999.89 -0.742933
# 3   0.3   9999.78 -1.114400
# 4   0.4   9999.63 -1.485860

# %%
fig1 = go.Figure()
fig1.add_trace(go.Scatter(x=df.Altitude,y=df.Velocity))
fig1.add_trace(go.Scatter(x=h,y=v))
iplot(fig1)
# Out:
# <div>                            <div id="00df6d2a-aa81-4760-9054-d70ed47f172c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("00df6d2a-aa81-4760-9054-d70ed47f172c")) {                    Plotly.newPlot(                        "00df6d2a-aa81-4760-9054-d70ed47f172c",                        [{"x":[10000.0,9999.96,9999.89,9999.78,9999.63,9999.44,9999.22,9998.96,9998.66,9998.33,9997.96,9997.55,9997.1,9996.62,9996.1,9995.54,9994.95,9994.32,9993.65,9992.94,9992.2,9991.42,9990.6,9989.75,9988.86,9987.93,9986.96,9985.96,9984.92,9983.85,9982.73,9981.58,9980.39,9979.17,9977.91,9976.61,9975.27,9973.9,9972.49,9971.04,9969.56,9968.03,9966.48,9964.88,9963.25,9961.58,9959.87,9958.13,9956.35,9954.53,9952.68,9950.79,9948.86,9946.89,9944.89,9942.85,9940.77,9938.66,99
# ...

# %%
df.describe()
# Out:
#               Time      Altitude     Velocity
# count  5191.000000   5191.000000  5191.000000
# mean    259.500000   2112.165158   -19.263231
# std     149.865695   2732.949793    22.968802
# min       0.000000      0.493846   -89.322400
# 25%     129.750000    172.157500   -28.930650
# 50%     259.500000    794.836000    -8.389640
# 75%     389.250000   3069.200000    -2.367205
# max     519.000000  10000.000000    -0.371467

# %% [markdown]
# # Scenario 3

# %%
h0 = 503.2
K_h = 0.00518
dff=pd.read_csv('lander_phase_space_3.csv')
h=np.arange(0, dff.Altitude.max(), 10000)
v=-(0.5 + K_h * h)
dff.head()
# Out:
#    Time  Altitude  Velocity
# 0   0.0   503.200   4689.23
# 1   0.1   977.816   4746.16
# 2   0.2  1424.880   4470.61
# 3   0.3  1848.460   4235.80
# 4   0.4  2251.750   4032.93

# %%
fig3 = go.Figure()
fig3.add_trace(go.Scatter(x=dff.Altitude,y=dff.Velocity))
fig3.add_trace(go.Scatter(x=h,y=v))
iplot(fig3)
# Out:
# <div>                            <div id="95c97907-99e5-4aac-80bf-6a433e4d2ada" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("95c97907-99e5-4aac-80bf-6a433e4d2ada")) {                    Plotly.newPlot(                        "95c97907-99e5-4aac-80bf-6a433e4d2ada",                        [{"x":[503.2,977.816,1424.88,1848.46,2251.75,2637.31,3007.21,3363.18,3706.65,4038.84,4360.78,4673.38,4977.41,5273.55,5562.41,5844.51,6120.32,6390.28,6654.75,6914.09,7168.6,7418.57,7664.25,7905.87,8143.67,8377.82,8608.52,8835.93,9060.21,9281.51,9499.95,9715.68,9928.8,10139.4,10347.6,10553.6,10757.3,10958.9,11158.5,11356.1,11551.8,11745.7,11937.8,12128.2,12316.9,12504.1,12689.8,12873.9,13056.6,13237.9,13417.9,13596.5,13773.9,13950.1,14125.0,14298.7,14471.4,14642.9,1
# ...

# %%
dff.describe()
# Out:
#                Time       Altitude      Velocity
# count  18322.000000   18322.000000  18322.000000
# mean     916.050000   61955.267377     -0.018434
# std      528.925015   77493.234776    401.513405
# min        0.000000       0.495267   -716.001000
# 25%      458.025000    1227.137500   -111.889750
# 50%      916.050000   13937.150000    -12.236800
# 75%     1374.075000  126898.500000     -1.178913
# max     1832.100000  213959.000000   4746.160000

# %% [markdown]
# # Scenario 5

# %%
h0 = 503.2
K_h = 0.004
dfff=pd.read_csv('lander_phase_space_5.csv')
h=np.arange(0, dfff.Altitude.max(), 10000)
v=-(0.5 + K_h * h)
dff.head()
# Out:
#    Time  Altitude  Velocity
# 0   0.0   503.200   4689.23
# 1   0.1   977.816   4746.16
# 2   0.2  1424.880   4470.61
# 3   0.3  1848.460   4235.80
# 4   0.4  2251.750   4032.93

# %%
fig5 = go.Figure()
fig5.add_trace(go.Scatter(x=dfff.Altitude,y=dfff.Velocity))
fig5.add_trace(go.Scatter(x=h,y=v))
iplot(fig5)
# Out:
# <div>                            <div id="110e8954-7446-458d-9e6c-23f97200aab6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("110e8954-7446-458d-9e6c-23f97200aab6")) {                    Plotly.newPlot(                        "110e8954-7446-458d-9e6c-23f97200aab6",                        [{"x":[200000.0,200000.0,200000.0,200000.0,200000.0,200000.0,199999.0,199999.0,199999.0,199999.0,199998.0,199998.0,199997.0,199997.0,199997.0,199996.0,199995.0,199995.0,199994.0,199994.0,199993.0,199992.0,199992.0,199991.0,199990.0,199989.0,199988.0,199987.0,199986.0,199986.0,199985.0,199983.0,199982.0,199981.0,199980.0,199979.0,199978.0,199977.0,199975.0,199974.0,199973.0,199971.0,199970.0,199968.0,199967.0,199966.0,199964.0,199962.0,199961.0,199959.0,199958.0,19
# ...

# %%
dfff.describe()
# Out:
#                Time       Altitude      Velocity
# count  18786.000000   18786.000000  18786.000000
# mean     939.250000   36683.964103   -106.462010
# std      542.319541   57110.775785    151.558783
# min        0.000000       0.499603   -592.738000
# 25%      469.625000     915.107250   -152.420500
# 50%      939.250000    6844.810000    -27.111200
# 75%     1408.875000   45627.725000     -4.253395
# max     1878.500000  200000.000000     -0.333147
